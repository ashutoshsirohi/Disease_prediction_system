# %%
import numpy as np
import pandas as pd
df1=pd.read_csv('taxi.csv')
df1
# Out:
#     Priceperweek  Population  Monthlyincome  Averageparkingpermonth  \
# 0             15     1800000           5800                      50
# 1             15     1790000           6200                      50
# 2             15     1780000           6400                      60
# 3             25     1778000           6500                      60
# 4             25     1750000           6550                      60
# 5             25     1740000           6580                      70
# 6             25     1725000           8200                      75
# 7             30     1725000           8600                      75
# 8             30     1720000           8800                      75
# 9             30     1705000           9200                      80
# 10            30     1710000           9630                      80
# 11            40     1700000          10570                      80
# 12            40     1695000          11330                      85
# ...

# %%
#import dataset
dataset1=pd.read_csv('taxi.csv')
dataset1
# Out:
#     Priceperweek  Population  Monthlyincome  Averageparkingpermonth  \
# 0             15     1800000           5800                      50
# 1             15     1790000           6200                      50
# 2             15     1780000           6400                      60
# 3             25     1778000           6500                      60
# 4             25     1750000           6550                      60
# 5             25     1740000           6580                      70
# 6             25     1725000           8200                      75
# 7             30     1725000           8600                      75
# 8             30     1720000           8800                      75
# 9             30     1705000           9200                      80
# 10            30     1710000           9630                      80
# 11            40     1700000          10570                      80
# 12            40     1695000          11330                      85
# ...

# %%
dataset1.shape
# Out:
# (27, 5)

# %%
dataset1.isnull().sum()
# Out:
# Priceperweek              0
# Population                0
# Monthlyincome             0
# Averageparkingpermonth    0
# Numberofweeklyriders      0
# dtype: int64

# %%
#seperation of dataset set intp dependent and independent data
x= dataset1.iloc[:,:-1].values
y= dataset1.iloc[:,4].values
x.shapen
# Out:
# (27, 4)

# %%
#seperation of dataset set into training and testing data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
reg= LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#file handeling

r=read
w=write
a=append
wb=write in binary
rb=read in binary

# %%
#--------important------------for python interview
#pickle/serielization
import pickle
pickle.dump(reg,open('dumbum.pkl','wb'))

# %%
from sklearn.metrics import r2_score
y_pred=reg.predict(x_test)
r2 = r2_score(y_test,y_pred)
print(r2)
# Out:
# 0.9157379222488218

# %%
model=pickle.load(open('dumbum.pkl','rb'))

# %%
model.predict([[80,1770000,6000,85]]).round(2)
# Out:
# array([153448.45])
